# %%
import re

# %%
content = "代號：10120-11120 104 年公務人員特種考試關務人員考試、104 年公務人員特種考試身心\n30120-30820\n障礙人員考試及 104 年國軍上校以上軍官轉任公務人員考試試題\n頁次：4－1\n考 試 別： 關務人員考試、身心障礙人員考試\n等 別： 三等考試\n類 科： 各科別、各類科\n科 目： 國文（作文、公文與測驗）\n考試時間： 2 小時 座號：\n※注意：禁止使用電子計算器。\n甲、作文與公文部分：\n\ue129請以藍、黑色鋼筆或原子筆在申論試卷上由左至右橫式作答，於本試題上作答者，不予計分。\n\ue12a不得於試卷上書寫姓名或入場證號。\n一、 作文：（60 分）\n關口可以是具體，也可以是抽象的；可以是形下，也可以是形上的。\n關口是追求夢想或帶來夢魘的異境；關口也是介於善與惡、合法與\n非法之際的特殊空間。光明與自由在此連線，利益與人性在此衝\n關口\n撞。請以「 」為題，作文一篇，述其思索所得。\n二、 公文：（20 分）\n桃園國際機場為臺灣國際航班起降的門戶，截至 103 年底，國際客\n運量排名居全球第 11 位。有鑒於「世界地球村，疫病無國界」，而\n旅客在旅途中，會有 20～70%出現健康與疾病傳染癥候，請試擬衛\n生福利部疾病管制署函直轄市及各縣市旅行商業同業公會，配合辦\n理檢疫、防疫措施，派員參加「104 年度導遊、領隊旅遊醫學教育訓\n練課程」，並檢附該署修正發布之「港埠檢疫規則」，以收宣導之效。\n乙、測驗部分：（20 分） 代號：2101\n\ue129本試題為單一選擇題，請選出一個正確或最適當的答案，複選作答者，該題不予計分。\n\ue12a共10題，每題2分，須用2B鉛筆在試卡上依題號清楚劃記，於本試題或申論試卷上作答者，不予計分。\n1 「終其一身／我的心／四處尋找著比喻：／『了解我……最起碼，試著，』／譬如\n地下掘出的龜甲／你可以如卜者／讀著我的心的裂縫／或著吃了它／如藥癒著你\n的病。」（〈龜甲〉）下列選項，何者較貼近這首詩的意旨？\n\ue18c凸顯現代人生活處境的艱難\n\ue18d道出知音尋索的困難與期望\n\ue18e展現年輕時有理想與堅持，卻在現實生命中逐漸失去活力\n\ue18f藉著超自然方式，期望對未來有所掌握，反映出人性對未知的憂慮與不安\n代號：10120-11120\n30120-30820\n頁次：4－2\n2 下列敘述，符合作者觀點的選項是：\n十八世紀的旅遊只侷限於歐洲菁英階段，十九世紀末到二十世紀，鐵路、汽車的發\n明把勞工帶進了休閒市場。到了二十世紀晚期，最不常度假的反而是發明旅遊的貴\n族們。貪得無饜的大老闆們，活在無限慾望的生產時代，權力的飢渴與瞠目結舌的\n財富追尋聯手起來，剝奪了當代貴族的休旅人權。他們沒得片刻休息，只能把旅行\n還給十八世紀時完全看不上眼的非菁英階級。（〈旅行是一首詩〉）\n\ue18c歷經一百多年的爭取，勞工終於享有平等的休閒旅遊人權\n\ue18d當代勞工因擁有較多休閒時間，所以成為旅遊的主要族群\n\ue18e大老闆為追逐財富而放棄旅遊，也剝奪員工們的旅遊時間\n\ue18f在經濟快速發展的當代，旅遊業卻因人們生活忙碌而沒落\n3 現在生命教育最迫切的是給年輕人生命的理想。人生的目的在於實現心中的理想，\n若是心中無理想，人生自然無目的，醉生夢死當然就成為生活的態度了。要實踐生\n命教育必須從實做中去求體驗，沒有體驗不會有感動，沒有感動就不會有學習。\n（《理直氣平：勇於改變才會進步》）下列選項何者不符本文意旨？\n\ue18c察己則可以知人，察今則可以知古\n\ue18d立志不真，故用功未免間斷，須從本原上徹底理會\n\ue18e學之之博，未若知之之要；知之之要，未若行之之實\n\ue18f為學先須立志。志既立，然後學問可次第著力。立志不定，終不濟事\n4 《柔性權力》一書提到：「權力的運用其實還有另一條間接路線；亦即某個國家若\n得以在國際政治中獲致其所欲結果的話，也可能是由於其他國家願意追隨它，欽慕\n其價值觀，學習其發展歷程，或渴望達到與其相同之繁榮與開放程度的緣故。」\n「柔性權力」一詞後轉為「軟實力」概念，並於今日廣泛使用，先秦諸子言論中何\n者與之最為接近？\n\ue18c故遠人不服，則修文德以來之。既來之，則安之（《論語‧季氏》）\n\ue18d刑生力，力生強，強生威，威生惠，惠生於力（《商君書‧去強》）\n\ue18e故聖人云：我無為而民自化，我好靜而民自正，我無事而民自富，我無欲而民自\n樸（《老子‧第五十七章》）\n\ue18f察國之所以治者何也？國君唯能壹同國之義，是以國治也。……天子唯能壹同\n天下之義，是以天下治也（《墨子‧尚同》）\n代號：10120-11120\n30120-30820\n頁次：4－3\n5 一個城，即使在人類思想的源頭上重要如雅典，仍因為它留下來的戲劇作品和劇場\n而更偉大；即使在民主體制的形成上重要如倫敦，仍因為它有莎士比亞而加倍榮耀。\n當然長安城若沒有了斗酒詩百篇的李白，若沒有過霓裳羽衣舞低楊柳的樓台，便只\n不過是個朝代興替的城池。（〈期待一個城市〉）下列選項對本段文意的闡述，何\n者錯誤？\n\ue18c每一座城市都應有自己的藝術與文化風氣\n\ue18d一座城市的歷史與經濟力，是使其成為世界性城市的原因\n\ue18e一座城市能因豐富的藝文活動，產生源源不絕的精神活力\n\ue18f雅典、倫敦、長安等歷史名城，皆因詩歌、舞蹈、戲劇增添了光彩\n6 《荀子‧不苟》：「君子崇人之德，揚人之美，非諂諛也；正義直指，舉人之過，\n非毀疵也；言己之光美，擬於舜禹，參於天地，非夸誕也；與時屈伸，柔從若蒲葦，\n非懾怯也；剛強猛毅，靡所不信，非驕暴也；以義變應，知當曲直故也。《詩》曰：\n『左之左之，君子宜之；右之右之，君子有之。』此言君子以義屈信變應故也。」下\n列敘述，何者最能說明本文主旨？\n\ue18c君子秉持中道褒貶他人，既不阿諛也不詆毀\n\ue18d君子出入行事謹守嚴以律己、寬以待人之道\n\ue18e君子以舜禹為師，自期俯仰天地間屈伸自如\n\ue18f君子以義變通應事，故無時無刻皆能得其宜\n7 孔、孟皇皇於一時，而師法於千萬世；韓氏之文，沒而不見者二百年，而後大施於\n今。此又非特好惡之所上下，蓋其久而愈明，不可磨滅，雖蔽於暫而終耀于無窮者，\n其道當然也。（歐陽修〈記舊本韓文後〉）根據上文，作者認為：\n\ue18c哲理、主張之流行與否，取決於時代風氣與世俗的好惡\n\ue18d所有哲思與理論，流行之前總會遭遇挫折，暫時被掩蓋\n\ue18e韓愈文章之所以能大行於世，乃因其本身的深厚而雄博\n\ue18f孔、孟之道所以能為千萬世所師法，乃是因漢代獨尊儒術的關係\n代號：10120-11120\n30120-30820\n頁次：4－4\n昔者彌子瑕有寵於衛君。衛國之法，竊駕君車者罪刖。彌子瑕母病，人聞夜往告\n彌子，彌子瑕矯駕君車以出。君聞而賢之，曰：「孝哉，為母之故，忘其刖罪。」異日，\n與君遊於果園，食桃而甘，不盡，以其半啗君。君曰：「愛我哉。忘其口味以啖寡人。」\n及彌子瑕色衰愛弛，得罪於君。君曰：「是固嘗矯駕吾車，又嘗啗我以餘桃。」故彌子\n瑕之行未變於初也，而以前之所以見賢而後獲罪者，愛憎之變也。（《韓非子‧說難》）\n依上文回答下列第 8 題至第 9 題：\n8 下列選項何者正確？\n\ue18c伴君如伴虎，彌子瑕不知謹言慎行，所以最終獲罪\n\ue18d彌子瑕愈發恃寵而驕、仗勢欺人，令衛君忍無可忍\n\ue18e彌子瑕愈發目中無人，得罪衛君左右臣子，衛君無法再袒護他\n\ue18f衛君對彌子瑕態度的轉變，在於其色衰愛弛，衛君愛憎已不同\n9 韓非子藉彌子瑕事，欲說明何種觀點？\n\ue18c虛則欹，中則正，滿則覆\n\ue18d上行下效，上有所好，下必甚焉\n\ue18e有下人之色，將枉於法；枉於法，則免於相\n\ue18f有愛於主則智當而加親，有憎於主則智不當見罪而加疏\n10 下列文句中的成語使用，完全正確的是：\n\ue18c我與好朋友們「三人成虎」，在比賽中克服種種困難，「不疾不徐」贏得最終勝利\n\ue18d陳主任自就職以來，在處事方面往往「削足適履」，不免令人產生「兔死狗烹」\n之感\n\ue18e王大明在家中「尸位素餐」，經過多年努力準備考試，終於「夙願以償」，進入\n公務機關服務\n\ue18f張教授以媚俗觀點詮釋《論語》，在媒體上大出鋒頭。論者認為這種作法，跟孔\n子「謙抑自持」的風範「大相逕庭」\n"

# 問題：正則表達式中的 (?=\n[\ue0c6-\ue0cf]+) 要求下一個題號前必須有換行符
# 但最後一題 \ue0cb 後面沒有換行符，所以無法匹配到 \ue0ca 開頭的題目
# 修改正則表達式，使最後一題也能被匹配

# 調整正則表達式，確保能捕捉到所有題目，包括最後一題
matches = re.findall(
    r"\n(\d{1,2})\s(.+?)(\n\ue18c.+?(?:\n\ue18d.+?)?(?:\n\ue18e.+?)?(?:\n\ue18f.+?)?)(?=\n\d+\s|\Z)",
    content,
    re.DOTALL,
)

for match in matches:
    print(match)
# Out:
# ('1', '「終其一身／我的心／四處尋找著比喻：／『了解我……最起碼，試著，』／譬如\n地下掘出的龜甲／你可以如卜者／讀著我的心的裂縫／或著吃了它／如藥癒著你\n的病。」（〈龜甲〉）下列選項，何者較貼近這首詩的意旨？', '\n\ue18c凸顯現代人生活處境的艱難\n\ue18d道出知音尋索的困難與期望\n\ue18e展現年輕時有理想與堅持，卻在現實生命中逐漸失去活力\n\ue18f藉著超自然方式，期望對未來有所掌握，反映出人性對未知的憂慮與不安\n代號：10120-11120\n30120-30820\n頁次：4－2')
# ('2', '下列敘述，符合作者觀點的選項是：\n十八世紀的旅遊只侷限於歐洲菁英階段，十九世紀末到二十世紀，鐵路、汽車的發\n明把勞工帶進了休閒市場。到了二十世紀晚期，最不常度假的反而是發明旅遊的貴\n族們。貪得無饜的大老闆們，活在無限慾望的生產時代，權力的飢渴與瞠目結舌的\n財富追尋聯手起來，剝奪了當代貴族的休旅人權。他們沒得片刻休息，只能把旅行\n還給十八世紀時完全看不上眼的非菁英階級。（〈旅行是一首詩〉）', '\n\ue18c歷經一百多年的爭取，勞工終於享有平等的休閒旅遊人權\n\ue18d當代勞工因擁有較多休閒時間，所以成為旅遊的主要族群\n\ue18e大老闆為追逐財富而放棄旅遊，也剝奪員工們的旅遊時間\n\ue18f在經濟快速發展的當代，旅遊業卻因人們生活忙碌而沒落')
# ('3', '現在生命教育最迫切的是給年輕人生命的理想。人生的目的在於實現心中的理想，\n若是心中無理想，人生自然無目的，醉生夢死當然就成為生活的態度了。要實踐生\n命教育必須從實做中去求體驗，沒有體驗不會有感動，沒有感動就不會有學習。\n（《理直氣平：勇於改變才會進步》）下列選項何者不符本文意旨？', '\n\ue18c察己則可以知人，察今則可以知古\n\ue18d立志不真，故用功未免間斷，須從本原上徹底理會\n\ue18e學之之博，未若知之之要；知之之要，未若行之之實\n\ue18f為學先須立志。志既立，然後學問可次第著力。立志不定，終不濟事')
# ...

# %%
choices_text = "\n\ue18c甲：「嫂夫人從南部回來了嗎？」／乙：「家嫂昨天剛回來。」\n\ue18d甲：「令妹的學習表現優異。」／乙：「感謝對家妹的照顧。」\n\ue18e甲：「請問醫生，家母情況如何？」／乙：「令堂的病況已經穩定了。」\n\ue18f甲：「舍兄囑咐我問候尊翁。」／乙：「託令兄的福，家父一切安好。」"
choices = re.findall(
    r"(?sm)[\ue18c-\ue18f](.*?)(?=\n[\ue18c-\ue18f]|\Z)",
    choices_text,
)

for choice in choices:
    print(choice)
    #print(choice.encode("unicode_escape").decode("utf-8"))
# Out:
# 甲：「嫂夫人從南部回來了嗎？」／乙：「家嫂昨天剛回來。」
# 甲：「令妹的學習表現優異。」／乙：「感謝對家妹的照顧。」
# 甲：「請問醫生，家母情況如何？」／乙：「令堂的病況已經穩定了。」
# 甲：「舍兄囑咐我問候尊翁。」／乙：「託令兄的福，家父一切安好。」

# %%
content = "\n4 3\n63"
print(content.encode('unicode_escape').decode('utf-8'))
content = re.sub(r"(?<=\n)(\d+\s+\d+)\n(\d+)", r"\2", content)
print(content.encode("unicode_escape").decode("utf-8"))

# %%
# 檢查題號
word = "\ue0c6下列對話中的稱呼用語，完全正確的選項是：'"

if re.match(
    r"^([\ue0c6|\ue0c7|\ue0c8|\ue0c9|\ue0ca|\ue0cb|\ue0cc|\ue0cd|\ue0ce|\ue0cf]).+$",
    word.strip(),
):  # 同時匹配全形(中文)和半形逗號
    number = word.split(".")[0]
    print(number)

# %%
# 檢查題號
word = "\n1 「終其一身／我的心／四處尋找著比喻：／『了解我……最起碼，試著，』／譬如\n地下掘出的龜甲／你可以如卜者／讀著我的心的裂縫／或著吃了它／如藥癒著你\n的病。」（〈龜甲〉）下列選項，何者較貼近這首詩的意旨？\n\ue18c凸顯現代人生活處境的艱難\n\ue18d道出知音尋索的困難與期望\n\ue18e展現年輕時有理想與堅持，卻在現實生命中逐漸失去活力\n\ue18f藉著超自然方式，期望對未來有所掌握，反映出人性對未知的憂慮與不安\n代號：10120-11120\n30120-30820\n頁次：4－2\n2 下列敘述，符合作者觀點的選項是"

if re.match(
    r"^\n\d+\s+",
    word,
):  # 同時匹配全形(中文)和半形逗號
    number = re.sub(
        r"^\n(\d+)\s+",
        r"\1",
        word,
    )

    print(number)
# Out:
# 1「終其一身／我的心／四處尋找著比喻：／『了解我……最起碼，試著，』／譬如
# 地下掘出的龜甲／你可以如卜者／讀著我的心的裂縫／或著吃了它／如藥癒著你
# 的病。」（〈龜甲〉）下列選項，何者較貼近這首詩的意旨？
# 凸顯現代人生活處境的艱難
# 道出知音尋索的困難與期望
# 展現年輕時有理想與堅持，卻在現實生命中逐漸失去活力
# 藉著超自然方式，期望對未來有所掌握，反映出人性對未知的憂慮與不安
# 代號：10120-11120
# 30120-30820
# 頁次：4－2
# 2 下列敘述，符合作者觀點的選項是

# %%
content = "\n\ue18c沉魚落雁／貌比無鹽／閉月羞花 \ue18d河清海晏／蜩螗沸羹／四海昇平\n\ue18e近朱近墨／涅而不緇／麻中蓬直 \ue18f咳唾成珠／揚葩振藻／擲地有聲\n（請接背面）\n101年公務人員特種考試關務人員考試、101年公務人員特種考試 全一張\n10110-11310\n代號：\n移民行政人員考試及101年國軍上校以上軍官轉任公務人員考試試題 50110-51110（ 背面）\n等 別： 三等關務人員考試、三等移民行政人員考試\n類（科）別： 各科別、移民行政\n科 目： 國文（作文、公文與測驗）\n\ue0ca下列各詩句對於視野空間的處理，何者由大至小，由遠至近？\n\ue18c千山鳥飛絕，萬徑人蹤滅。孤舟簑笠翁，獨釣寒江雪（柳宗元〈江雪〉）\n\ue18d眾鳥高飛盡，孤雲獨去閒。相看兩不厭，只有敬亭山（李白〈獨坐敬亭山〉）\n\ue18e風急天高猿嘯哀，渚清沙白鳥飛迴。無邊落木蕭蕭下，不盡長江滾滾來（杜甫\n〈登高〉）\n\ue18f獨憐幽草澗邊生，上有黃鸝深樹鳴。春潮帶雨晚來急，野渡無人舟自橫（韋應\n物〈滁州西澗〉）"

# 無法成功替換的原因可能有：
# 1. 正則表達式模式不匹配實際內容
# 2. 編碼問題導致字符無法正確識別
# 3. 特殊字符需要額外處理

# 讓我們先印出要匹配的部分，看看實際內容
print("要替換的文字：", re.findall(r"\uff08\u8acb\u63a5.+\u6e2c\u9a57\uff09", content, re.DOTALL))

# 使用更精確的模式，確保能匹配到目標文字
content = re.sub(
    r"\n\uff08\u8acb\u63a5\u80cc\u9762\uff09.*?\u6e2c\u9a57\uff09",
    "",
    content,
    flags=re.DOTALL
)

# 如果上面的方法不行，可以嘗試直接使用中文字符
# content = re.sub(
#     r"（請接背面）.*?測驗）",
#     "",
#     content,
#     flags=re.DOTALL
# )

# match = re.match(r"\n.+(\uff08\u8acb\u63a5.+\u6e2c\u9a57\uff09)\n", content, re.DOTALL | re.MULTILINE)
# match = re.findall(
#     r"\uff08\u8acb\u63a5.+\u6e2c\u9a57\uff09", content, re.DOTALL | re.MULTILINE
# )
# print(match[0])
# print(content.encode("unicode_escape").decode("utf-8"))
print(content)
